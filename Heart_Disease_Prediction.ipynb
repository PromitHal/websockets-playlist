# %% [markdown]
# <a href="https://colab.research.google.com/github/PromitHal/websockets-playlist/blob/master/Heart_Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9a179c3f-62a4-4b87-8804-3dd8369975ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a179c3f-62a4-4b87-8804-3dd8369975ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart (4).csv to heart (4).csv

# %%
import io 
Data=pd.read_csv(io.BytesIO(uploaded['heart (4).csv']))

# %%
Data.head(50)
# Out:
#     age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0    63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1    37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2    41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3    56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4    57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# 5    57    1   0       140   192    0  ...      0      0.4      1   0     1       1
# 6    56    0   1       140   294    0  ...      0      1.3      1   0     2       1
# 7    44    1   1       120   263    0  ...      0      0.0      2   0     3       1
# 8    52    1   2       172   199    1  ...      0      0.5      2   0     3       1
# 9    57    1   2       150   168    0  ...      0      1.6      2   0     2       1
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
f=sns.countplot(x='target',data=Data)
f.set_title("Heart disease distribution")
f.set_xticklabels(['No Heart disease', 'Heart Disease'])
plt.xlabel("");

# %%
f = sns.countplot(x='target', data=Data,hue='sex' )
plt.legend(['Female', 'Male'])
f.set_title("Heart disease by gender")
f.set_xticklabels(['No Heart disease', 'Heart Disease'])
plt.xlabel("");

# %%
heat_map = sns.heatmap(Data.corr(method='pearson'), annot=True,
fmt='.2f', linewidths=2)
heat_map.set_xticklabels(heat_map.get_xticklabels(), rotation=45);
plt.rcParams["figure.figsize"] = (50,50)

# %%
Data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
Y=Data['target']

# %%
X=Data.drop(columns=['target'],axis=1)

# %%
X.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  thalach  exang  oldpeak  slope  ca  thal
# 0   63    1   3       145   233    1  ...      150      0      2.3      0   0     1
# 1   37    1   2       130   250    0  ...      187      0      3.5      0   0     2
# 2   41    0   1       130   204    0  ...      172      0      1.4      2   0     2
# 3   56    1   1       120   236    0  ...      178      0      0.8      2   0     2
# 4   57    0   0       120   354    0  ...      163      1      0.6      2   0     2
#
# [5 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#      age  sex  cp  trestbps  chol  ...  exang  oldpeak  slope  ca  thal
# 237   60    1   0       140   293  ...      0      1.2      1   2     3
# 106   69    1   3       160   234  ...      0      0.1      1   1     2
# 10    54    1   0       140   239  ...      0      1.2      2   0     2
# 153   66    0   2       146   278  ...      0      0.0      1   1     2
# 77    59    1   1       140   221  ...      1      0.0      2   0     2
# ..   ...  ...  ..       ...   ...  ...    ...      ...    ...  ..   ...
# 75    55    0   1       135   250  ...      0      1.4      1   0     2
# 22    42    1   0       140   226  ...      0      0.0      2   0     2
# 72    29    1   1       130   204  ...      0      0.0      2   0     2
# 15    50    0   2       120   219  ...      0      1.6      1   0     2
# 168   63    1   0       130   254  ...      0      1.4      1   1     3
#
# [242 rows x 13 columns]

# %%
Y_train
# Out:
# 237    0
# 106    1
# 10     1
# 153    1
# 77     1
#       ..
# 75     1
# 22     1
# 72     1
# 15     1
# 168    0
# Name: target, Length: 242, dtype: int64

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(100,input_dim=13,activation='tanh'))
model.add(Dense(150, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,Y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 4ms/step - loss: 0.6841 - accuracy: 0.5826
# Epoch 2/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6449 - accuracy: 0.6033
# Epoch 3/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6258 - accuracy: 0.6570
# Epoch 4/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6177 - accuracy: 0.6653
# Epoch 5/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6368 - accuracy: 0.6240
# Epoch 6/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6174 - accuracy: 0.6529
# Epoch 7/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5974 - accuracy: 0.6529
# Epoch 8/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.6736
# Epoch 9/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6031 - accuracy: 0.6446
# Epoch 10/100
# ...

# %%
model.summary()
score = model.evaluate(X_test,Y_test, verbose=0)
print('Model Accuracy = ',score[1])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 100)               1400
#
#  dense_22 (Dense)            (None, 150)               15150
#
#  dense_23 (Dense)            (None, 200)               30200
#
#  dense_24 (Dense)            (None, 1)                 201
#
# ...
# Total params: 46,951
# Trainable params: 46,951
# Non-trainable params: 0
# _________________________________________________________________
# Model Accuracy =  0.8524590134620667
